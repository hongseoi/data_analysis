# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

# %%
#크롤링할 페이지 불러오기
url = "https://www.livesport.com/kr/team/manchester-united/ppjDR086/"
html = urlopen(url)
bs_obj01 = BeautifulSoup(html, "html.parser")
win01 = bs_obj01.find_all("span", {"class":"wld wld--l"})
win01
# Out:
# []

# %%
bs_obj01
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD XHTML 1.1//EN" "http://www.w3.org/TR/xhtml11/DTD/xhtml11.dtd">
#
# <html lang="ko" xml:lang="ko" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <meta content="IE=11" http-equiv="X-UA-Compatible"/>
# <title>Livesport: 맨체스터 유나이티드 - 결과, 일정, 맨체스터 유나이티드 vs 리버풀 live</title>
# <link as="script" href="https://cdn.cookielaw.org/scripttemplates/otSDKStub.js" rel="preload"/>
# <link as="fetch" crossorigin="" href="https://cdn.cookielaw.org/vendorlist/iab2Data.json" rel="preload"/>
# <noscript>
# <meta content="0;URL='https://m.flashscore.co.kr/'" http-equiv="refresh"/>
# </noscript>
# <meta content="" name="keywords"/>
# <meta content="맨체스터 유나이티드 점수 및 일정 - Livesport.com에서 맨체스터 유나이티드의 라이브스코어, 결과, 일정, 자세한 경기내용을 확인하세요.&lt;br /&gt;
# " name="description"/>
# <meta content="Copyright (c) 2012-2022 Livesport s.r.o." name="copyright"/>
# <meta content="NOODP,index,follow" name="robots"/>
# ...
