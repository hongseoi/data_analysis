# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen

# %%
endpoint = "https://infuser.odcloud.kr/api/stages/27795/api-docs?1647332194450"

serviceKey = "8F+z/ubqBl3Mj/2VtQVgj/FytAZ2kWY3hC4O8gdq4b+w4aLiuLCu9OULSAJoXH98doe8Eu/9oj1jiJv9p0G6Hw=="

startmonth = "201901"
endmonth = "202012"
region = "11110"
tradingtype="05"

# %%
url = endpoint + "?" \
    "serviceKey="+serviceKey+\
    "&"+"startmonth="+startmonth+\
    "&"+"endmonth="+endmonth+\
    "&"+"region="+region+\
    "&"+"tradingtype="+tradingtype

html = urlopen(url)
bs_obj = BeautifulSoup(html, "html.parser")
print(bs_obj)
# Out:
# {"swagger":"2.0","info":{"version":"1","title":"부동산 거래 통계 조회 서비스","description":"한국부동산원(구.한국감정원)에서 제공하는 부동산 거래 통계를 조회할 수 있는 서비스로 토지거래현황, 순수토지 거래현황, 건축물 거래현황, 주택 거래현황, 아파트 거래현황, 주택매매거래현황, 아파트매매거래현황, 토지매매거래현황 데이터를 제공합니다.\n\n-----------------------------------------------------------------------------\n ** EQ(Equal) : =\n ** LT(Little) : &lt;\n ** LTE(Little or Equal) : &lt;=\n ** GT(Greater) : &gt;\n ** GTE(Greater or Equal) : &gt;=\n (조사일자 : 21년 1월 ~ 21년 12월 (GTE(202101) &lt;= 조사일자 &lt;= LTE(202112)))"},"host":"api.odcloud.kr","basePath":"/api","schemes":["https","http"],"securityDefinitions":{"ApiKeyAuth":{"type":"apiKey","in":"header","name":"Authorization"},"ApiKeyAuth2":{"type":"apiKey","in":"query","name":"serviceKey"}},"paths":{"/RealEstateTradingSvc/v1/getRealEstateTradingArea":{"get":{"tags":["API 목록"],"summary":"부동산 거래 면적 조회","operationId":"getgetRealEstateTradingArea","description":"조사일자, 지역코드, 거래유형 값을 이용하여 부동산 거래 면적 정보를 제공","consumes":["application/json"],"produces":["appli
# ...

# %%
#데이터를 리스트 형태로 만들기
regi = bs_obj.find("REGION_NM").text
print(regi)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\HONGSE~1\AppData\Local\Temp/ipykernel_20464/2677424604.py in <module>
#       1 #데이터를 리스트 형태로 만들기
# ----> 2 regi = bs_obj.find("REGION_NM").text
#       3 print(regi)
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
trade = bs_obj.find("rsrow").text
print(trade)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\HONGSE~1\AppData\Local\Temp/ipykernel_20464/222676735.py in <module>
# ----> 1 trade = bs_obj.find("rsrow").text
#       2 print(trade)
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
data = trade.split("|")
print(data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\HONGSE~1\AppData\Local\Temp/ipykernel_20464/347082359.py in <module>
# ----> 1 data = trade.split("|")
#       2 print(data)
#
# NameError: name 'trade' is not defined

# %%
value = data[0].split(",")
print(value)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\HONGSE~1\AppData\Local\Temp/ipykernel_20464/490767994.py in <module>
# ----> 1 value = data[0].split(",")
#       2 print(value)
#
# NameError: name 'data' is not defined

# %%
row = [regi, value[0], int(value[1])]
print(row)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\HONGSE~1\AppData\Local\Temp/ipykernel_20464/1619451958.py in <module>
# ----> 1 row = [regi, value[0], int(value[1])]
#       2 print(row)
#       3
#       4
#
# NameError: name 'value' is not defined

# %%
#리스트를 데이터 프레임으로
import pandas as pd

df = pd.DataFrame(columns=['지역','날짜','거래건수'])
df
# Out:
# Empty DataFrame
# Columns: [지역, 날짜, 거래건수]
# Index: []

# %%
#데이터프레임의 열 이름 확인
df.columns
# Out:
# Index(['지역', '날짜', '거래건수'], dtype='object')

# %%
df_row = pd.Series(row, index=col)
df_low
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\HONGSE~1\AppData\Local\Temp/ipykernel_20464/3578545002.py in <module>
# ----> 1 df_row = pd.Series(row, index=col)
#       2 df_low
#
# NameError: name 'row' is not defined

# %%
df.append(df_row, ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\HONGSE~1\AppData\Local\Temp/ipykernel_20464/4981867.py in <module>
# ----> 1 df.append(df_row, ignore_index=True)
#
# NameError: name 'df_row' is not defined

# %%
#반복문을 이용해 결과 한번에 입력
n = len(data)
for i in range(0,n):
    value = data[1].split(',')
    row = [regi, value[0], int(value[1])]
    df_row = pd.Series(row, index=col)
    df = df.append(df_row, ignore_index=True)
print(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\HONGSE~1\AppData\Local\Temp/ipykernel_20464/3748831904.py in <module>
#       1 #반복문을 이용해 결과 한번에 입력
# ----> 2 n = len(data)
#       3 for i in range(0,n):
#       4     value = data[1].split(',')
#       5     row = [regi, value[0], int(value[1])]
#
# NameError: name 'data' is not defined

# %%
#matplotlib로 시각화학
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.plot(df['날짜'],df['거래 건수'],color='b',marker='o')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\dataanalysis\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# C:\dataanalysis\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# C:\dataanalysis\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '거래 건수'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...
