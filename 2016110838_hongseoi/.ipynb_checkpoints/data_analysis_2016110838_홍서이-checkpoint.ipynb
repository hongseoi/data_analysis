# %% [markdown]
# **The relationship between installing CCTV and crime rate**
# <br><br>
# 2016110838 행정학전공 홍서이

# %% [markdown]
# **Before data analysis**
# - import libraries
# - set font for Korean

# %%
# import library
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os
import math
import seaborn as sns
from scipy import stats
import statsmodels.formula.api as smf

# !pip install folium
import folium
geo_json = "https://raw.githubusercontent.com/southkorea/seoul-maps/master/kostat/2013/json/seoul_municipalities_geo_simple.json"
# Out:
# Requirement already satisfied: folium in c:\dataanalysis\lib\site-packages (0.12.1.post1)
# Requirement already satisfied: numpy in c:\dataanalysis\lib\site-packages (from folium) (1.20.3)
# Requirement already satisfied: jinja2>=2.9 in c:\dataanalysis\lib\site-packages (from folium) (2.11.3)
# Requirement already satisfied: branca>=0.3.0 in c:\dataanalysis\lib\site-packages (from folium) (0.5.0)
# Requirement already satisfied: requests in c:\dataanalysis\lib\site-packages (from folium) (2.26.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\dataanalysis\lib\site-packages (from jinja2>=2.9->folium) (1.1.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\dataanalysis\lib\site-packages (from requests->folium) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\dataanalysis\lib\site-packages (from requests->folium) (3.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\dataanalysis\lib\site-packages (from requests->folium) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\dataanalysis\lib\site-packages (from requests->folium) (1.26.7)

# %%
# Setting a Hangul font for data visualization

plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus']=False

# %% [markdown]
# **Creating DataFrames and organizing data**
#
# In this notebook, I would like to analyze the relationship between CCTV and crime.
# For this analysis, I will integrate a total of four pieces of data.
# - data1 = Crime in Seoul, 2020
# - data2 = Number of CCTV setup in Seoul up to 2021
# - data3 = urbanization Area per district in Seoul
# - data4 = Population in Seoul, 2020
# - data5 = Number of crimes by age in Seoul, 2020

# %%
# data1: crime in Seoul in 2020
crime = pd.read_csv('crime_seoul(2020).csv', encoding='cp949')
crime.head()
# Out:
#    자치구  전체 범죄 발생 건수  전체 범죄 검거 건수 살인 발생 건수 살인 검거 건수  강도 발생 건수  강도 검거 건수  \
# 0  종로구         3102         3343        9        7         7         9
# 1   중구         3411         2323        2        2         5         6
# 2  용산구         2969         2056        5        3         6         6
# 3  성동구         2362         1774        5        5         3         3
# 4  광진구         3601         2511        2        2         4         4
#
#    강간강제추행 발생 건수  강간강제추행 검거 건수  절도 발생 건수  절도 검거 건수  폭력 발생 건수  폭력 검거 건수
# 0           192           855      1183       944      1711      1528
# 1           186           128      1642       863      1576      1324
# 2           230           186      1111       534      1617      1327
# 3           115            98      1016       565      1223      1103
# 4           255           224      1664       874      1676      1407

# %%
# Get necessary colunms for hypothesis from data1
crime = crime[['자치구', '전체 범죄 발생 건수']]
crime.head()
# Out:
#    자치구  전체 범죄 발생 건수
# 0  종로구         3102
# 1   중구         3411
# 2  용산구         2969
# 3  성동구         2362
# 4  광진구         3601

# %%
#data2 : Number of CCTV setup in Seoul up to 2021
cctv_setup = pd.read_csv('cctv_setup_seoul.csv', encoding='cp949')
cctv_setup.head()
# Out:
#    자치구  cctv 총계  2012년 이전  2012년  2013년  2014년  2015년  2016년  2017년  2018년  \
# 0  종로구   1772.0     813.0    0.0    0.0  210.0  150.0    1.0  261.0   85.0
# 1  중 구   2333.0      16.0  114.0   87.0   77.0  236.0  240.0  372.0  386.0
# 2  용산구   2383.0      34.0   71.0  234.0  125.0  221.0  298.0  351.0  125.0
# 3  성동구   3602.0     448.0  125.0  212.0  105.0  339.0  310.0  874.0  390.0
# 4  광진구   2588.0      35.0   57.0  100.0  187.0   98.0   52.0  675.0  465.0
#
#    2019년  2020년  2021년 신규 설치 cctv 개수
# 0    9.0  200.0                 43.0
# 1  155.0  361.0                289.0
# 2  307.0  617.0                  0.0
# 3  262.0  461.0                 76.0
# 4  712.0  175.0                 32.0

# %%
# Get necessary colunms for hypothesis from data2
cctv_setup = cctv_setup[['자치구','cctv 총계','2021년 신규 설치 cctv 개수']]
cctv_setup['cctv(2020)'] = cctv_setup['cctv 총계'] - cctv_setup['2021년 신규 설치 cctv 개수']
cctv_setup
# Out:
#      자치구  cctv 총계  2021년 신규 설치 cctv 개수  cctv(2020)
# 0    종로구   1772.0                 43.0      1729.0
# 1    중 구   2333.0                289.0      2044.0
# 2    용산구   2383.0                  0.0      2383.0
# 3    성동구   3602.0                 76.0      3526.0
# 4    광진구   2588.0                 32.0      2556.0
# 5   동대문구   2497.0                 63.0      2434.0
# 6    중랑구   3296.0                  4.0      3292.0
# 7    성북구   3958.0                188.0      3770.0
# 8    강북구   2462.0                 39.0      2423.0
# 9    도봉구   1629.0                331.0      1298.0
# 10   노원구   2415.0                104.0      2311.0
# 11   은평구   3791.0                131.0      3660.0
# 12  서대문구   2940.0                  1.0      2939.0
# 13   마포구   2421.0                 20.0      2401.0
# 14   양천구   3312.0                  0.0      3312.0
# 15   강서구   2560.0                123.0      2437.0
# 16   구로구   4075.0                  0.0      4075.0
# 17   금천구   2374.0                  9.0      2365.0
# 18  영등포구   3778.0                  5.0      3773.0
# 19   동작구   2297.0                 11.0      2286.0
# 20   관악구   4942.0                 34.0      4908.0
# 21   서초구   3704.0                  3.0      3701.0
# 22   강남구   6502.0                  1.0      6501.0
# 23   송파구   2854.0                101.0      2753.0
# 24   강동구   2547.0                  0.0      2547.0
# 25   NaN      NaN                  NaN         NaN

# %%
# data3 = Area per district in Seoul
area_seoul = pd.read_csv('using_area_seoul.csv')
area_seoul
# Out:
#      자치구  행정구역면적  시가화면적  시가화면적비율
# 0    서울시  605.24  12.77    53.39
# 1    종로구   23.91   9.95    99.89
# 2     중구    9.96  13.37    61.14
# 3    용산구   21.87  12.47    73.98
# 4    성동구   16.86  11.80    69.16
# 5    광진구   17.06  13.86    97.52
# 6   동대문구   14.22  11.18    60.44
# 7    중랑구   18.50  18.23    74.17
# 8    성북구   24.57  11.25    47.67
# 9    강북구   23.60   9.84    47.61
# 10   도봉구   20.66  14.57    41.11
# 11   노원구   35.44  15.89    53.47
# 12   은평구   29.71  15.72    89.20
# 13  서대문구   17.63  14.33    60.09
# 14   마포구   23.85  13.43    77.14
# 15   양천구   17.41  18.96    45.76
# 16   강서구   41.44  14.98    74.45
# 17   구로구   20.12  10.12    77.70
# 18   금천구   13.02  15.65    63.74
# 19  영등포구   24.55  14.14    86.44
# 20   동작구   16.35  15.72    53.16
# 21   관악구   29.57  20.21    43.01
# 22   서초구   46.98  26.17    66.26
# 23   강남구   39.50  23.30    68.79
# 24   송파구   33.87  13.65    55.49
# 25   강동구   24.59    NaN      NaN

# %%
# Get necessary colunms for hypothesis from data3
area_seoul = area_seoul[['자치구','시가화면적']]
area_seoul.head()
# Out:
#    자치구  시가화면적
# 0  서울시  12.77
# 1  종로구   9.95
# 2   중구  13.37
# 3  용산구  12.47
# 4  성동구  11.80

# %%
# data4 = Population in Seoul
# 1. Delete NaN

population = pd.read_csv('population_in_seoul.csv', encoding='cp949')
population = population.dropna()
population.head()
# Out:
#     자치구 성별         계     0~4세     5~9세   10~14세   15~19세   20~24세   25~29세  \
# 0   종로구  계  151581.0   3290.0   4293.0   4730.0   6309.0  14153.0  14905.0
# 3    중구  계  126467.0   3520.0   3501.0   2874.0   4031.0   9243.0  12269.0
# 6   용산구  계  222307.0   6496.0   7183.0   6926.0   8125.0  13739.0  19916.0
# 9   성동구  계  319475.0  10995.0  10819.0   9256.0  11771.0  24254.0  31057.0
# 12  광진구  계  357176.0   9533.0  11321.0  11641.0  13908.0  28813.0  39030.0
#
#      30~34세  ...   50~54세   55~59세   60~64세   65~69세   70~74세  75~79세  80~84세  \
# 0   10983.0  ...  12351.0  12218.0  11019.0   7797.0   6159.0  5404.0  3546.0
# 3   10768.0  ...  10010.0  10343.0   9871.0   7102.0   5385.0  4347.0  2787.0
# 6   19336.0  ...  17944.0  17209.0  15678.0  10904.0   8540.0  7162.0  4971.0
# 9   27860.0  ...  25208.0  24814.0  22266.0  15151.0  11495.0  9103.0  5640.0
# 12  31142.0  ...  28443.0  27781.0  25451.0  17297.0  12453.0  9389.0  5725.0
#
#     85~89세  90~94세  95세 이상+
# 0   1666.0   589.0     163.0
# 3   1294.0   503.0     108.0
# 6   2245.0   838.0     201.0
# 9   2488.0   823.0     201.0
# 12  2524.0   860.0     217.0
#
# [5 rows x 23 columns]

# %%
# data5 = "2020 서울시 연령별 범죄횟수.xls"
age_crime = pd.read_excel("raw_data/2020 서울시 연령별 범죄횟수.xls", header=1)
age_crime
# Out:
#      기간  서울시      합계  14세미만  14∼19  20∼25  26∼30  31~35  36~40  41∼50  51∼60  \
# 0  2020  서울시  326222      8  12736  25102  27657  24384  28514  58614  63765
#
#    61∼70  71세이상     미상
# 0  35782  14779  34881

# %% [markdown]
# As we see "2020 서울시 연령별 범죄횟수.xls", It is shown that there are only 8 crimes by offenders under the age of 14 in Seoul in 2020. Therefore, I will exclude the number of people under the age of 14 from the '계' column of the 'population_in_seoul.csv' file, which means the total number of people in each district in Seoul.

# %%
# Get necessary colunms for hypothesis from data4
# 2. Get necessary columns

population = population[['자치구','계','0~4세','5~9세','10~14세']]
population.head()
# Out:
#     자치구         계     0~4세     5~9세   10~14세
# 0   종로구  151581.0   3290.0   4293.0   4730.0
# 3    중구  126467.0   3520.0   3501.0   2874.0
# 6   용산구  222307.0   6496.0   7183.0   6926.0
# 9   성동구  319475.0  10995.0  10819.0   9256.0
# 12  광진구  357176.0   9533.0  11321.0  11641.0

# %%
# Get necessary colunms for hypothesis from data4
# 3. Make a new column, population in Seoul per distinct up to 15 years old

population['15세이상인구'] = population['계'] - population['0~4세'] - population['5~9세'] - population['10~14세']
population.head()
# Out:
#     자치구         계     0~4세     5~9세   10~14세   15세이상인구
# 0   종로구  151581.0   3290.0   4293.0   4730.0  139268.0
# 3    중구  126467.0   3520.0   3501.0   2874.0  116572.0
# 6   용산구  222307.0   6496.0   7183.0   6926.0  201702.0
# 9   성동구  319475.0  10995.0  10819.0   9256.0  288405.0
# 12  광진구  357176.0   9533.0  11321.0  11641.0  324681.0

# %%
# Merge 1~4 dataset, make a DataFrame "df"
df = pd.merge(area_seoul, cctv_setup)
df = pd.merge(df, crime)
df = pd.merge(df, population)
df.head()
# Out:
#     자치구  시가화면적  cctv 총계  2021년 신규 설치 cctv 개수  cctv(2020)  전체 범죄 발생 건수  \
# 0   종로구   9.95   1772.0                 43.0      1729.0         3102
# 1   용산구  12.47   2383.0                  0.0      2383.0         2969
# 2   성동구  11.80   3602.0                 76.0      3526.0         2362
# 3   광진구  13.86   2588.0                 32.0      2556.0         3601
# 4  동대문구  11.18   2497.0                 63.0      2434.0         3401
#
#           계     0~4세     5~9세   10~14세   15세이상인구
# 0  151581.0   3290.0   4293.0   4730.0  139268.0
# 1  222307.0   6496.0   7183.0   6926.0  201702.0
# 2  319475.0  10995.0  10819.0   9256.0  288405.0
# 3  357176.0   9533.0  11321.0  11641.0  324681.0
# 4  355917.0  10117.0  11247.0  10616.0  323937.0

# %%
# Make new columns from df
df['범죄율'] = df['전체 범죄 발생 건수']/df['15세이상인구']
df['면적당cctv개수'] = df['cctv(2020)']/df['시가화면적']

df.head()
# Out:
#     자치구  시가화면적  2021년 신규 설치 cctv 개수  cctv(2020)  전체 범죄 발생 건수         계  \
# 0   종로구   9.95                 43.0      1729.0         3102  151581.0
# 1   용산구  12.47                  0.0      2383.0         2969  222307.0
# 2   성동구  11.80                 76.0      3526.0         2362  319475.0
# 3   광진구  13.86                 32.0      2556.0         3601  357176.0
# 4  동대문구  11.18                 63.0      2434.0         3401  355917.0
#
#       0~4세     5~9세   10~14세   15세이상인구       범죄율   면적당cctv개수
# 0   3290.0   4293.0   4730.0  139268.0  0.022274  173.768844
# 1   6496.0   7183.0   6926.0  201702.0  0.014720  191.098637
# 2  10995.0  10819.0   9256.0  288405.0  0.008190  298.813559
# 3   9533.0  11321.0  11641.0  324681.0  0.011091  184.415584
# 4  10117.0  11247.0  10616.0  323937.0  0.010499  217.710197

# %%
# remain unnecessary columns in df

df = df[['자치구','범죄율','면적당cctv개수']]
df.head()
# Out:
#     자치구       범죄율   면적당cctv개수
# 0   종로구  0.022274  173.768844
# 1   용산구  0.014720  191.098637
# 2   성동구  0.008190  298.813559
# 3   광진구  0.011091  184.415584
# 4  동대문구  0.010499  217.710197

# %%
# data visualization
# 1. Crime rate per capita in Seoul

df.plot.bar(x='자치구', y='범죄율', rot=0, figsize=(25,10))
plt.show()

m = folium.Map(
    location  = [37.566345, 126.977893],
    zoom_start=10,
    titles = 'Stamen Terrain')

folium.Choropleth(
geo_data = geo_json,
data = df,
columns = ['자치구','범죄율'],
key_on='properties.name',
fill_color='BuPu',
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d14a6b48b0304e71aac6142332ed386c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d14a6b48b0304e71aac6142332ed386c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_d14a6b48b0304e71aac6142332ed386c = L.map(
#                 &quot;map_d14a6b48b0304e71aac6142332ed386c&quot;,
#                 {
#                     center: [37.566345, 126.977893],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     titles: &quot;Stamen Terrain&quot;,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7d56c477effca6120b970273327500ae = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_d14a6b48b0304e71aac6142332ed386c);
#
#
#             var choropleth_0aeddee0cdb1a1adce90df7d114dec87 = L.featureGroup(
#                 {}
#             ).addTo(map_d14a6b48b0304e71aac6142332ed386c);
#
#
#         function geo_json_888af18369a3059caf9353c72fdba969_styler(feature) {
#             switch(feature.properties.code) {
#                 case &quot;11230&quot;: case &quot;11190&quot;: case &quot;11030&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#8c96c6&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;11220&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#9ebcda&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;11200&quot;: case &quot;11160&quot;: case &quot;11150&quot;: case &quot;11130&quot;: case &quot;11120&quot;: case &quot;11110&quot;: case &quot;11100&quot;: case &quot;11080&quot;: case &quot;11040&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#edf8fb&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;11020&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;11010&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#810f7c&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#bfd3e6&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_888af18369a3059caf9353c72fdba969_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_888af18369a3059caf9353c72fdba969 = L.geoJson(null, {
#                 onEachFeature: geo_json_888af18369a3059caf9353c72fdba969_onEachFeature,
#
#                 style: geo_json_888af18369a3059caf9353c72fdba969_styler,
#         });
#
#         function geo_json_888af18369a3059caf9353c72fdba969_add (data) {
#             geo_json_888af18369a3059caf9353c72fdba969
#                 .addData(data)
#                 .addTo(choropleth_0aeddee0cdb1a1adce90df7d114dec87);
#         }
#             geo_json_888af18369a3059caf9353c72fdba969_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.11519584981606, 37.557533180704915], [127.11879551821994, 37.557222485451305], [127.12146867175024, 37.55986003393365], [127.12435254630417, 37.56144246249796], [127.13593925898998, 37.56564793048277], [127.14930548011061, 37.56892250303897], [127.15511020940411, 37.57093642128295], [127.16683184366129, 37.57672487388627], [127.17038810813094, 37.576465605301046], [127.17607118428914, 37.57678573961056], [127.17905504160184, 37.57791388161732], [127.17747787800164, 37.57448983055031], [127.1781775408844, 37.571481967974336], [127.17995281860672, 37.569309661290504], [127.18122821955262, 37.56636089217979], [127.18169407550688, 37.56286338914073], [127.18408792330152, 37.55814280369575], [127.18350810324185, 37.550053002101485], [127.1852644795464, 37.54888592026534], [127.18480906237207, 37.545296888806796], [127.18543378919821, 37.54260756512178], [127.18364810569703, 37.54241347907019], [127.18116465939269, 37.54384126582126], [127.17770860504257, 37.542414255164374], [127.1744373170213, 37.54277723796397], [127.16830424484573, 37.54145405702079], [127.16530984307447, 37.54221851258693], [127.15566835118616, 37.53119520531309], [127.15538075046105, 37.52652930087977], [127.15154315998161, 37.522828709496416], [127.14981542759394, 37.51926843453025], [127.14791518058246, 37.51918714979303], [127.14684644251928, 37.51661384818575], [127.14672806

# %%
# 2. numbers of CCTV per area in Seoul
df.plot.bar(x='자치구', y='면적당cctv개수', rot=0, figsize=(25,10))
plt.show()


m = folium.Map(
    location  = [37.566345, 126.977893],
    zoom_start=10,
    titles = 'Stamen Terrain')

folium.Choropleth(
geo_data = geo_json,
data = df,
columns = ['자치구','면적당cctv개수'],
key_on='properties.name',
fill_color='BuPu',
).add_to(m)


m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_37654c0a09589b09fdb6fb060eefad40 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_37654c0a09589b09fdb6fb060eefad40&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_37654c0a09589b09fdb6fb060eefad40 = L.map(
#                 &quot;map_37654c0a09589b09fdb6fb060eefad40&quot;,
#                 {
#                     center: [37.566345, 126.977893],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     titles: &quot;Stamen Terrain&quot;,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3a91dbf7ac6ee1c8c00ad295ac337cbd = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_37654c0a09589b09fdb6fb060eefad40);
#
#
#             var choropleth_32cdcc5f0d0e0e9e4c75e989569a890a = L.featureGroup(
#                 {}
#             ).addTo(map_37654c0a09589b09fdb6fb060eefad40);
#
#
#         function geo_json_e9663b600e726ff214b096723949ca8f_styler(feature) {
#             switch(feature.properties.code) {
#                 case &quot;11250&quot;: case &quot;11020&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;11240&quot;: case &quot;11210&quot;: case &quot;11130&quot;: case &quot;11120&quot;: case &quot;11060&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#9ebcda&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;11230&quot;: case &quot;11190&quot;: case &quot;11090&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#8c96c6&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;11170&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#810f7c&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;11100&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#edf8fb&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;11080&quot;: case &quot;11040&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#8856a7&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#bfd3e6&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_e9663b600e726ff214b096723949ca8f_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_e9663b600e726ff214b096723949ca8f = L.geoJson(null, {
#                 onEachFeature: geo_json_e9663b600e726ff214b096723949ca8f_onEachFeature,
#
#                 style: geo_json_e9663b600e726ff214b096723949ca8f_styler,
#         });
#
#         function geo_json_e9663b600e726ff214b096723949ca8f_add (data) {
#             geo_json_e9663b600e726ff214b096723949ca8f
#                 .addData(data)
#                 .addTo(choropleth_32cdcc5f0d0e0e9e4c75e989569a890a);
#         }
#             geo_json_e9663b600e726ff214b096723949ca8f_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.11519584981606, 37.557533180704915], [127.11879551821994, 37.557222485451305], [127.12146867175024, 37.55986003393365], [127.12435254630417, 37.56144246249796], [127.13593925898998, 37.56564793048277], [127.14930548011061, 37.56892250303897], [127.15511020940411, 37.57093642128295], [127.16683184366129, 37.57672487388627], [127.17038810813094, 37.576465605301046], [127.17607118428914, 37.57678573961056], [127.17905504160184, 37.57791388161732], [127.17747787800164, 37.57448983055031], [127.1781775408844, 37.571481967974336], [127.17995281860672, 37.569309661290504], [127.18122821955262, 37.56636089217979], [127.18169407550688, 37.56286338914073], [127.18408792330152, 37.55814280369575], [127.18350810324185, 37.550053002101485], [127.1852644795464, 37.54888592026534], [127.18480906237207, 37.545296888806796], [127.18543378919821, 37.54260756512178], [127.18364810569703, 37.54241347907019], [127.18116465939269, 37.54384126582126], [127.17770860504257, 37.542414255164374], [127.1744373170213, 37.54277723796397], [127.16830424484573, 37.54145405702079], [127.16530984307447, 37.54221851258693], [127.15566835118616, 37.53119520531309], [127.15538075046105, 37.52652930087977

# %% [markdown]
# # Regression analysis
# The hypothesis is "The number of CCTV will affect the crime rate.".
#
# In this paper, "범죄율" means "전체 범죄 건수"/"15세 이상 인구수".
# X is '면적당 cctv 개수' and Y is '범죄율'.
#
# By doing Regression analysis, I will check the relationship between X and Y.

# %%
##1.1 distplot(X)
sns.distplot(df['면적당cctv개수'])
# Out:
# C:\dataanalysis\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='면적당cctv개수', ylabel='Density'>

# %%
## 1.2 log(X)
df['log_cctv'] = df['면적당cctv개수'].apply(math.log)

## 1.3 displot(log(X))
sns.distplot(df['log_cctv'])
# Out:
# C:\dataanalysis\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='log_cctv', ylabel='Density'>

# %%
# scatter(y,x1)
x = df.log_cctv
y = df.범죄율

plt.scatter(y,x,alpha=0.5)

# %%
# regression analysis: Y and X
df_ols = smf.ols('범죄율~log_cctv',df).fit()
df_ols.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    범죄율   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                 -0.044
# Method:                 Least Squares   F-statistic:                   0.06645
# Date:                Fri, 27 May 2022   Prob (F-statistic):              0.799
# Time:                        18:57:55   Log-Likelihood:                 97.803
# No. Observations:                  23   AIC:                            -191.6
# Df Residuals:                      21   BIC:                            -189.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0077      0.012      0.624      0.539      -0.018       0.033
# log_cctv       0.0006      0.002      0.258      0.799      -0.004       0.005
# ==============================================================================
# Omnibus:                       17.169   Durbin-Watson:                   1.028
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               18.943
# Skew:                           1.645   Prob(JB):                     7.70e-05
# Kurtosis:                       5.990   Cond. No.                         90.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """
