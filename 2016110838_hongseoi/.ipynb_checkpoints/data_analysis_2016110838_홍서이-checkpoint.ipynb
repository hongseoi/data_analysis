# %% [markdown]
# **The relationship between istalling CCTV and crime**
# <br><br>
# 2016110838 행정학전공 홍서이

# %% [markdown]
# **Before data analysis**
# - import libraries
# - set font for Korean

# %%
# import library
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os
import math
import seaborn as sns
from scipy import stats
import statsmodels.formula.api as smf

# %%
# font for data visualization

plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus']=False

# %% [markdown]
# **Creating DataFrames and organizing data**
#
# In this notebook, I would like to analyze the relationship between CCTV and crime.
# For this analysis, I will integrate a total of four pieces of data.
# - data1: crime in Seoul in 2020
# - data2 : Distinctive CCTV setup in Seoul up to 2021
# - data3 = Area per district in Seoul
# - data4 = Population in Seoul

# %%
# data1: crime in Seoul in 2020
crime = pd.read_csv('crime_seoul(2020).csv', encoding='cp949')
crime.head()
# Out:
#    자치구  전체 범죄 발생 건수  전체 범죄 검거 건수 살인 발생 건수 살인 검거 건수  강도 발생 건수  강도 검거 건수  \
# 0  종로구         3102         3343        9        7         7         9
# 1   중구         3411         2323        2        2         5         6
# 2  용산구         2969         2056        5        3         6         6
# 3  성동구         2362         1774        5        5         3         3
# 4  광진구         3601         2511        2        2         4         4
#
#    강간강제추행 발생 건수  강간강제추행 검거 건수  절도 발생 건수  절도 검거 건수  폭력 발생 건수  폭력 검거 건수
# 0           192           855      1183       944      1711      1528
# 1           186           128      1642       863      1576      1324
# 2           230           186      1111       534      1617      1327
# 3           115            98      1016       565      1223      1103
# 4           255           224      1664       874      1676      1407

# %%
#data2 : Distinctive CCTV setup in Seoul up to 2021
cctv_setup = pd.read_csv('cctv_setup_seoul.csv', encoding='cp949')
cctv_setup.head()
# Out:
#    자치구  cctv 총계  2012년 이전  2012년  2013년  2014년  2015년  2016년  2017년  2018년  \
# 0  종로구   1772.0     813.0    0.0    0.0  210.0  150.0    1.0  261.0   85.0
# 1  중 구   2333.0      16.0  114.0   87.0   77.0  236.0  240.0  372.0  386.0
# 2  용산구   2383.0      34.0   71.0  234.0  125.0  221.0  298.0  351.0  125.0
# 3  성동구   3602.0     448.0  125.0  212.0  105.0  339.0  310.0  874.0  390.0
# 4  광진구   2588.0      35.0   57.0  100.0  187.0   98.0   52.0  675.0  465.0
#
#    2019년  2020년  2021년 신규 설치 cctv 개수
# 0    9.0  200.0                 43.0
# 1  155.0  361.0                289.0
# 2  307.0  617.0                  0.0
# 3  262.0  461.0                 76.0
# 4  712.0  175.0                 32.0

# %%
# data3 = Area per district in Seoul
area_seoul = pd.read_csv('area_seoul.csv', encoding='cp949')
area_seoul.head()
# Out:
#    자치구     면적  전체 면적 대비 구성비(%)   행정동   법정동      통       반
# 0  종로구  23.91             3.95  17.0  87.0  279.0  1475.0
# 1   중구   9.96             1.65  15.0  74.0  253.0  1580.0
# 2  용산구  21.87             3.61  16.0  36.0  354.0  2581.0
# 3  성동구  16.86             2.79  17.0  17.0  467.0  3626.0
# 4  광진구  17.06             2.82  15.0   7.0  363.0  2999.0

# %%
# data4 = Population in Seoul
population = pd.read_csv('population_in_seoul.csv', encoding='cp949')
population.head()
# Out:
#    자치구  성별         계    0~4세    5~9세  10~14세  15~19세   20~24세   25~29세  \
# 0  종로구   계  151581.0  3290.0  4293.0  4730.0  6309.0  14153.0  14905.0
# 1  NaN  남자   73323.0  1660.0  2181.0  2402.0  3258.0   6529.0   7326.0
# 2  NaN  여자   78258.0  1630.0  2112.0  2328.0  3051.0   7624.0   7579.0
# 3   중구   계  126467.0  3520.0  3501.0  2874.0  4031.0   9243.0  12269.0
# 4  NaN  남자   60956.0  1746.0  1781.0  1447.0  1930.0   4020.0   6042.0
#
#     30~34세  ...   50~54세   55~59세   60~64세  65~69세  70~74세  75~79세  80~84세  \
# 0  10983.0  ...  12351.0  12218.0  11019.0  7797.0  6159.0  5404.0  3546.0
# 1   5573.0  ...   5994.0   6059.0   5450.0  3733.0  2750.0  2335.0  1445.0
# 2   5410.0  ...   6357.0   6159.0   5569.0  4064.0  3409.0  3069.0  2101.0
# 3  10768.0  ...  10010.0  10343.0   9871.0  7102.0  5385.0  4347.0  2787.0
# 4   5378.0  ...   4939.0   5050.0   4839.0  3360.0  2420.0  1829.0  1059.0
#
#    85~89세  90~94세  95세 이상+
# 0  1666.0   589.0     163.0
# 1   586.0   175.0      42.0
# 2  1080.0   414.0     121.0
# 3  1294.0   503.0     108.0
# 4   392.0   133.0      27.0
#
# [5 rows x 23 columns]

# %%
# remove unnecessary data in population

population = population[['자치구','성별','계']]
population = population.dropna()
population = population[['자치구','계']]
population
# Out:
#      자치구         계
# 0    종로구  151581.0
# 3     중구  126467.0
# 6    용산구  222307.0
# 9    성동구  319475.0
# 12   광진구  357176.0
# 15  동대문구  355917.0
# 18   중랑구  384950.0
# 21   성북구  437443.0
# 24   강북구  301489.0
# 27   도봉구  321875.0
# 30   노원구  517866.0
# 33   은평구  463468.0
# 36  서대문구  317323.0
# 39   마포구  366037.0
# 42   양천구  437848.0
# 45   강서구  578840.0
# 48   구로구  427307.0
# 51   금천구  248496.0
# 54  영등포구  389064.0
# 57   동작구  401650.0
# 60   관악구  507757.0
# 63   서초구  403569.0
# 66   강남구  505092.0
# 69   송파구  658321.0
# 72   강동구  400375.0

# %%
# Extract necessary columns from dataset

area_seoul = area_seoul[['자치구','면적']]
cctv_setup = cctv_setup[['자치구','cctv 총계', '2021년 신규 설치 cctv 개수']]
crime = crime[['자치구','전체 범죄 발생 건수', '전체 범죄 검거 건수']]

print(area_seoul.head(5))
print(cctv_setup.head(5))
print(population.head(5))
print(crime.head(5))
# Out:
#    자치구     면적
# 0  종로구  23.91
# 1   중구   9.96
# 2  용산구  21.87
# 3  성동구  16.86
# 4  광진구  17.06
#    자치구  cctv 총계  2021년 신규 설치 cctv 개수
# 0  종로구   1772.0                 43.0
# 1  중 구   2333.0                289.0
# 2  용산구   2383.0                  0.0
# 3  성동구   3602.0                 76.0
# 4  광진구   2588.0                 32.0
#     자치구         계
# 0   종로구  151581.0
# 3    중구  126467.0
# 6   용산구  222307.0
# 9   성동구  319475.0
# 12  광진구  357176.0
#    자치구  전체 범죄 발생 건수  전체 범죄 검거 건수
# 0  종로구         3102         3343
# 1   중구         3411         2323
# 2  용산구         2969         2056
# 3  성동구         2362         1774
# 4  광진구         3601         2511

# %%
# Make a DataFrame by using 3 datasets
df = pd.merge(area_seoul, cctv_setup)
df = pd.merge(df, crime)
df = pd.merge(df, population)
df
# Out:
#      자치구     면적  cctv 총계  2021년 신규 설치 cctv 개수  전체 범죄 발생 건수  전체 범죄 검거 건수  \
# 0    종로구  23.91   1772.0                 43.0         3102         3343
# 1    용산구  21.87   2383.0                  0.0         2969         2056
# 2    성동구  16.86   3602.0                 76.0         2362         1774
# 3    광진구  17.06   2588.0                 32.0         3601         2511
# 4   동대문구  14.22   2497.0                 63.0         3401         2465
# 5    중랑구  18.50   3296.0                  4.0         3726         2781
# 6    성북구  24.58   3958.0                188.0         2567         1947
# 7    강북구  23.60   2462.0                 39.0         2770         2259
# 8    도봉구  20.65   1629.0                331.0         2179         1490
# 9    노원구  35.44   2415.0                104.0         3743         2581
# 10   은평구  29.71   3791.0                131.0         3390         2531
# 11  서대문구  17.63   2940.0                  1.0         2533         1706
# 12   마포구  23.85   2421.0                 20.0         3688         2534
# 13   양천구  17.41   3312.0                  0.0         3216         2086
# 14   강서구  41.44   2560.0                123.0         4415         3393
# 15   구로구  20.12   4075.0                  0.0         4175         2984
# 16   금천구  13.02   2374.0                  9.0         2598         1966
# 17  영등포구  24.55   3778.0                  5.0         5217         3371
# 18   동작구  16.35   2297.0                 11.0         3200         2086
# 19   관악구  29.57   4942.0                 34.0         5261         3858
# 20   서초구  46.98   3704.0                  3.0         4601         3052
# 21   강남구  39.50   6502.0                  1.0         7356         5245
# 22   송파구  33.87   2854.0                101.0         5410         3544
# 23   강동구  24.59   2547.0                  0.0         3788         2662
#
#            계
# 0   151581.0
# 1   222307.0
# 2   319475.0
# 3   357176.0
# 4   355917.0
# 5   384950.0
# 6   437443.0
# 7   301489.0
# 8   321875.0
# 9   517866.0
# 10  463468.0
# 11  317323.0
# 12  366037.0
# 13  437848.0
# 14  578840.0
# 15  427307.0
# 16  248496.0
# 17  389064.0
# 18  401650.0
# 19  507757.0
# 20  403569.0
# 21  505092.0
# 22  658321.0
# 23  400375.0

# %%
# copy df for Column Calculation

df_copy = df.copy()

# %%
# Make new columns for using in regression analysis
# 1. number of cctv per area in 2020

 ##1.1 Get cctv installation data up to 2020
df['cctv(2020)'] = df_copy['cctv 총계'] - df_copy['2021년 신규 설치 cctv 개수']

 ## 1.2 get number of cctv per area in 2020
df_copy['cctv(2020)'] = df['cctv(2020)']
df['면적당_cctv_개수'] = df_copy['cctv(2020)'] / df_copy['면적']

 ##1.3 drop used data: cctv 총계, 2021년 신규 설치 cctv 개수, cctv(2020)
del df['cctv 총계']
del df['2021년 신규 설치 cctv 개수']
del df['cctv(2020)']
del df['면적']
df
# Out:
#      자치구  전체 범죄 발생 건수  전체 범죄 검거 건수         계  면적당_cctv_개수
# 0    종로구         3102         3343  151581.0    72.312840
# 1    용산구         2969         2056  222307.0   108.962048
# 2    성동구         2362         1774  319475.0   209.134045
# 3    광진구         3601         2511  357176.0   149.824150
# 4   동대문구         3401         2465  355917.0   171.167370
# 5    중랑구         3726         2781  384950.0   177.945946
# 6    성북구         2567         1947  437443.0   153.376729
# 7    강북구         2770         2259  301489.0   102.669492
# 8    도봉구         2179         1490  321875.0    62.857143
# 9    노원구         3743         2581  517866.0    65.208804
# 10   은평구         3390         2531  463468.0   123.190845
# 11  서대문구         2533         1706  317323.0   166.704481
# 12   마포구         3688         2534  366037.0   100.670860
# 13   양천구         3216         2086  437848.0   190.235497
# 14   강서구         4415         3393  578840.0    58.807915
# 15   구로구         4175         2984  427307.0   202.534791
# 16   금천구         2598         1966  248496.0   181.643625
# 17  영등포구         5217         3371  389064.0   153.686354
# 18   동작구         3200         2086  401650.0   139.816514
# 19   관악구         5261         3858  507757.0   165.979033
# 20   서초구         4601         3052  403569.0    78.778203
# 21   강남구         7356         5245  505092.0   164.582278
# 22   송파구         5410         3544  658321.0    81.281370
# 23   강동구         3788         2662  400375.0   103.578691

# %%
# 2. Number of crimes in Seoul per capita
## 2.1 Make Number of crimes in Seoul per capita
df['인당_범죄율'] = df_copy['전체 범죄 발생 건수'] / df_copy['계']

df
# Out:
#      자치구  전체 범죄 발생 건수  전체 범죄 검거 건수         계  면적당_cctv_개수    인당_범죄율
# 0    종로구         3102         3343  151581.0    72.312840  0.020464
# 1    용산구         2969         2056  222307.0   108.962048  0.013355
# 2    성동구         2362         1774  319475.0   209.134045  0.007393
# 3    광진구         3601         2511  357176.0   149.824150  0.010082
# 4   동대문구         3401         2465  355917.0   171.167370  0.009556
# 5    중랑구         3726         2781  384950.0   177.945946  0.009679
# 6    성북구         2567         1947  437443.0   153.376729  0.005868
# 7    강북구         2770         2259  301489.0   102.669492  0.009188
# 8    도봉구         2179         1490  321875.0    62.857143  0.006770
# 9    노원구         3743         2581  517866.0    65.208804  0.007228
# 10   은평구         3390         2531  463468.0   123.190845  0.007314
# 11  서대문구         2533         1706  317323.0   166.704481  0.007982
# 12   마포구         3688         2534  366037.0   100.670860  0.010075
# 13   양천구         3216         2086  437848.0   190.235497  0.007345
# 14   강서구         4415         3393  578840.0    58.807915  0.007627
# 15   구로구         4175         2984  427307.0   202.534791  0.009770
# 16   금천구         2598         1966  248496.0   181.643625  0.010455
# 17  영등포구         5217         3371  389064.0   153.686354  0.013409
# 18   동작구         3200         2086  401650.0   139.816514  0.007967
# 19   관악구         5261         3858  507757.0   165.979033  0.010361
# 20   서초구         4601         3052  403569.0    78.778203  0.011401
# 21   강남구         7356         5245  505092.0   164.582278  0.014564
# 22   송파구         5410         3544  658321.0    81.281370  0.008218
# 23   강동구         3788         2662  400375.0   103.578691  0.009461

# %%
# 3. Number of Criminal Arrests per capita
## 3.1 Make Number of Criminal Arrests per capita
df['검거율'] = df_copy['전체 범죄 검거 건수'] / df_copy['전체 범죄 발생 건수']

##3.2 Delete used data
del df['계']
del df['전체 범죄 검거 건수']
del df['전체 범죄 발생 건수']
df
# Out:
#      자치구  면적당_cctv_개수    인당_범죄율       검거율
# 0    종로구    72.312840  0.020464  1.077692
# 1    용산구   108.962048  0.013355  0.692489
# 2    성동구   209.134045  0.007393  0.751058
# 3    광진구   149.824150  0.010082  0.697306
# 4   동대문구   171.167370  0.009556  0.724787
# 5    중랑구   177.945946  0.009679  0.746377
# 6    성북구   153.376729  0.005868  0.758473
# 7    강북구   102.669492  0.009188  0.815523
# 8    도봉구    62.857143  0.006770  0.683800
# 9    노원구    65.208804  0.007228  0.689554
# 10   은평구   123.190845  0.007314  0.746608
# 11  서대문구   166.704481  0.007982  0.673510
# 12   마포구   100.670860  0.010075  0.687093
# 13   양천구   190.235497  0.007345  0.648632
# 14   강서구    58.807915  0.007627  0.768516
# 15   구로구   202.534791  0.009770  0.714731
# 16   금천구   181.643625  0.010455  0.756736
# 17  영등포구   153.686354  0.013409  0.646157
# 18   동작구   139.816514  0.007967  0.651875
# 19   관악구   165.979033  0.010361  0.733321
# 20   서초구    78.778203  0.011401  0.663334
# 21   강남구   164.582278  0.014564  0.713023
# 22   송파구    81.281370  0.008218  0.655083
# 23   강동구   103.578691  0.009461  0.702746

# %%
# data visualization
# 1. Crime occurrence and arrest per capita in Seoul

df.plot.bar(x='자치구', y='인당_범죄율', rot=0, figsize=(25,10))
plt.show()

# %%
df.plot.bar(x='자치구', y='검거율', rot=0, figsize=(25,10))
plt.show()

# %%
# 2. numbers of CCTV per area in Seoul
df.plot.bar(x='자치구', y='면적당_cctv_개수', rot=0, figsize=(25,10))
plt.show()

# %%
df.columns
# Out:
# Index(['자치구', '면적당_cctv_개수', '인당_범죄율', '검거율'], dtype='object')

# %%
df.head(5)
# Out:
#     자치구  면적당_cctv_개수    인당_범죄율       검거율
# 0   종로구    72.312840  0.020464  1.077692
# 1   용산구   108.962048  0.013355  0.692489
# 2   성동구   209.134045  0.007393  0.751058
# 3   광진구   149.824150  0.010082  0.697306
# 4  동대문구   171.167370  0.009556  0.724787

# %% [markdown]
# # Regression analysis
# The hypothesis is "The number of CCTV will affect the crime rate.".
#
# In this paper, crime rate means "전체 범죄 건수"/"구의 전체 인구수"
# And in that theory, X is '면적당 cctv 개수' and Y is '인당 범죄발생건수'.
#
# By doing Regression analysis, I will check the relationship between X and Y.

# %%
##1.1 distplot(X)
sns.distplot(df['면적당_cctv_개수'])
# Out:
# C:\dataanalysis\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='면적당_cctv_개수', ylabel='Density'>

# %%
## 1.2 log(X)
df['log_cctv'] = df['면적당_cctv_개수'].apply(math.log)

## 1.3 displot(log(X))
sns.distplot(df['log_cctv'])
# Out:
# C:\dataanalysis\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='log_cctv', ylabel='Density'>

# %%
# scatter(y,x1)
x = df.log_cctv
y = df.인당_범죄율

plt.scatter(x,y,alpha=0.5)

# %%
# regression analysis: Y and X
df_ols = smf.ols('인당_범죄율~log_cctv',df).fit()
df_ols.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 인당_범죄율   R-squared:                       0.006
# Model:                            OLS   Adj. R-squared:                 -0.039
# Method:                 Least Squares   F-statistic:                    0.1317
# Date:                Thu, 26 May 2022   Prob (F-statistic):              0.720
# Time:                        01:30:08   Log-Likelihood:                 104.72
# No. Observations:                  24   AIC:                            -205.4
# Df Residuals:                      22   BIC:                            -203.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0127      0.008      1.576      0.129      -0.004       0.029
# log_cctv      -0.0006      0.002     -0.363      0.720      -0.004       0.003
# ==============================================================================
# Omnibus:                       16.952   Durbin-Watson:                   1.058
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               18.966
# Skew:                           1.599   Prob(JB):                     7.61e-05
# Kurtosis:                       5.956   Cond. No.                         62.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# **short conclusion**

# %% [markdown]
# ** How about criminal arrest rate and CCTV?**
# X is '면적당 cctv 개수' and Y is '인당 범죄검거건수'.

# %%
# scatter(y,x2)
x = df.log_cctv
y = df.검거율

plt.scatter(x,y,alpha=0.5)

# %%
# regression analysis: Y and X2
df_ols = smf.ols('검거율~log_cctv',df).fit()
df_ols.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    검거율   R-squared:                       0.040
# Model:                            OLS   Adj. R-squared:                 -0.004
# Method:                 Least Squares   F-statistic:                    0.9082
# Date:                Thu, 26 May 2022   Prob (F-statistic):              0.351
# Time:                        01:33:48   Log-Likelihood:                 25.554
# No. Observations:                  24   AIC:                            -47.11
# Df Residuals:                      22   BIC:                            -44.75
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.9327      0.219      4.263      0.000       0.479       1.386
# log_cctv      -0.0431      0.045     -0.953      0.351      -0.137       0.051
# ==============================================================================
# Omnibus:                       32.102   Durbin-Watson:                   1.443
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               78.159
# Skew:                           2.430   Prob(JB):                     1.07e-17
# Kurtosis:                      10.385   Cond. No.                         62.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# **Short Conclusion**
# There is no relation between CCTV and crime in Seoul
